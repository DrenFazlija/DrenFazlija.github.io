# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# ...
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# %cd _talks/
# Out:
# /Users/dren/Code/GithubWebPage/DrenFazlija.github.io/_talks
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
g = glob.glob("*.md")

# %%
g
# Out:
# ['2024-04-10-talk.md',
#  '2014-02-01-talk-2.md',
#  '2024-05-08-talk.md',
#  '2024-06-14-talk.md',
#  '2024-04-16-talk.md',
#  '2013-03-01-tutorial-1.md',
#  '2024-05-26-talk.md',
#  '2012-03-01-talk-1.md']

# %%
geocoder = Nominatim(user_agent="drenfazlija-webpage")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Brainhouse 247, Laatzen, Lower Saxony, Germany
#  Brainhouse 247, 1-7, Hildesheimer Straße, Alt-Laatzen, Laatzen, Region Hannover, Niedersachsen, 30880, Deutschland
# Stanford University, Stanford, California, USA
#  Stanford University, 408, Panama Mall, Stanford, Santa Clara County, California, 94305, United States
# Ada-und-Theodor-Lessing Volkshochschule, Hannover, Lower Saxony, Germany
#  Ada-und-Theodor-Lessing-Volkshochschule, 14, Burgstraße, Kreuzkirchenviertel, Mitte, Hannover, Region Hannover, Niedersachsen, 30159, Deutschland
# Berufsbildende Schule Burgdorf, Burgdorf, Lower Saxony, Germany
#  Berufsbildende Schule Burgdorf, Berliner Ring, Burgdorf - Südstadt, Hülptingsen, Burgdorf, Region Hannover, Niedersachsen, 31303, Deutschland
# Gymnasium am Markt, Achim, Lower Saxony, Germany
#  Gymnasium am Markt, 18, Am Marktplatz, Uesen, Achim, Landkreis Verden, Niedersachsen, 28832, Deutschland
# Leibnizhaus, Hannover, Lower Saxony, Germany
# ...

# %%
geocoder.geocode("Berliner Allee 20, 30175 Hannover, Germany")
# Out:
# Location(Ärztekammer Niedersachsen, 20, Berliner Allee, Mitte, Hannover, Region Hannover, Niedersachsen, 30175, Deutschland, (52.3748064, 9.7506356, 0.0))

# %%
location_dict
# Out:
# {'Brainhouse 247, Laatzen, Lower Saxony, Germany': Location(Brainhouse 247, 1-7, Hildesheimer Straße, Alt-Laatzen, Laatzen, Region Hannover, Niedersachsen, 30880, Deutschland, (52.320846700000004, 9.786749304728716, 0.0)),
#  'Stanford University, Stanford, California, USA': Location(Stanford University, 408, Panama Mall, Stanford, Santa Clara County, California, 94305, United States, (37.431313849999995, -122.16936535498309, 0.0)),
#  'Ada-und-Theodor-Lessing Volkshochschule, Hannover, Lower Saxony, Germany': Location(Ada-und-Theodor-Lessing-Volkshochschule, 14, Burgstraße, Kreuzkirchenviertel, Mitte, Hannover, Region Hannover, Niedersachsen, 30159, Deutschland, (52.3727322, 9.7311288, 0.0)),
#  'Berufsbildende Schule Burgdorf, Burgdorf, Lower Saxony, Germany': Location(Berufsbildende Schule Burgdorf, Berliner Ring, Burgdorf - Südstadt, Hülptingsen, Burgdorf, Region Hannover, Niedersachsen, 31303, Deutschland, (52.43327455, 10.013943237123769, 0.0)),
# ...

# %%
new_addresses = [
    "Lange Laube 6, Hannover, Lower Saxony, Germany",
    "Barbarastraße 7, Dortmund, Germany",
    "Friedrich-Paffrath-Straße 101, Wilhelmshaven, Germany"
]

for address in new_addresses:
    location_dict[address] = geocoder.geocode(address)
    print(address, "\n", location_dict[address])
# Out:
# Lange Laube 6, Hannover, Lower Saxony, Germany
#  Peter Pane, 6, Lange Laube, Altstadt, Mitte, Hannover, Region Hannover, Niedersachsen, 30159, Deutschland
# Barbarastraße 7, Dortmund, Germany
#  Ehem. Torhaus Zeche Adolf von Hansemann 1/2/3, 7, Barbarastraße, Widum Mengede, Mengede, Dortmund, Nordrhein-Westfalen, 44357, Deutschland
# Friedrich-Paffrath-Straße 101, Wilhelmshaven, Germany
#  Hauptgebäude, 101, Friedrich-Paffrath-Straße, Rüstringer Stadtpark, Wilhelmshaven, Niedersachsen, 26389, Deutschland

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
